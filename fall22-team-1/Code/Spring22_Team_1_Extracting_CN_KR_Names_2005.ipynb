# %%
from google_patent_scraper import scraper_class
from bs4 import BeautifulSoup

# %%
import csv
import json

# %%
list_docs = list(range(2005,2023))
print(len(list_docs))
list_docs
# Out:
# 18
# [2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022]

# %% [markdown]
# # Reading and Counting All Team 1 Processed Data

# %%
total_rows = 0

total_kr = 0
total_cn = 0
total_both = 0

head = None

for i in list_docs:
    
    file_name = str(i) + "_patent_grant_processed.csv"
    
    print("\n"+"-"*30 + file_name + "-"*30)

    with open("Team 1 Processed Data/"+file_name, 'r',encoding="utf8") as file:
        csvreader = csv.reader(file)
        
        count = 0
        
        china_count = 0
        korea_count = 0
        both_count = 0

        for row in csvreader:
            
            if count==0:
                print(len(row))
                if row!=head:
                    head = row
                    print("----------HEAD CHANGE----------")
            
            count+=1
            
            if count<5:
                print(row)
                print(row[9])
                print(row[1])
                
                
            if 'KR' in row[9] and 'CN' in row[9]:
                both_count+=1
                
            elif 'KR' in row[9]:
                korea_count+=1
            
            elif 'CN' in row[9]:
                china_count+=1            
          
    print("\n")
    print("No of rows in document-",count)
    print("No of both CN & KR in document-",both_count)
    print("No of CN in document-",china_count)
    print("No of KR in document-",korea_count)
    
    print("\n")
    
    total_rows += count
    total_both += both_count
    total_kr += korea_count
    total_cn += china_count

print("\n\n")
print("Total no of rows in all documents-",total_rows)
print("Total CN & KR in all documents-",total_both)
print("Total CN in all documents-",total_cn)
print("Total KR in all documents-",total_kr)

print(head)
# Out:
# ------------------------------2005_patent_grant_processed.csv------------------------------
# 20
# ----------HEAD CHANGE----------
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US06838142', 'B2', '20050104', 'US09861015', '20010518', 'US', "['Yang Jie', 'Mazurek Mieczyslaw H.', 'Fleming Patrick R.', 'Meixner Larry A.', 'Mikami Haruyuki']", "['Jie', 'Mieczyslaw H.', 'Patrick R.', 'Larry A.', 'Haruyuki']", "['US', 'US', 'US', 'US', 'JP']", 'Specular laminates', '18', "['Lambert Nancy M.']", "['Nancy M.']", '5', '0', '5', '0', '1', '1']
# ['US', 'US', 'US', 'US', 'JP']
# US06838142
# ['1', 'US06838143', 'B2', '20050104', 'US09799620', '20010307', 'DE', "['Staller Christelle', 'Schumacher Karl-Heinz', 'Hartz Oliver', 'Röckel Harald']", "['Christelle', 'Karl-Heinz', 'Oliver', 'Harald']", "['FR', 'DE', 'DE', 'DE']", 'Peelable protective film', '10', '[]', '[]', '2', '2', '4', '0', '0', '0']
# ['FR', 'DE', 'DE', 'DE']
# US06838143
# ['2', 'US06836940', 'B2', '20050104', 'US09974441', '20011011', 'JP', "['Usui Minoru', 'Shimada Masato', 'Murai Masami', 'Sumi Kouji', 'Nishiwaki Tsutomu']", "['Minoru', 'Masato', 'Masami', 'Kouji', 'Tsutomu']", "['JP', 'JP', 'JP', 'JP', 'JP']", 'Process for producing a laminated ink-jet recording head', '11', '[]', '[]', '5', '0', '5', '0', '0', '0']
# ['JP', 'JP', 'JP', 'JP', 'JP']
# US06836940
#
#
# No of rows in document- 160990
# No of both CN & KR in document- 3
# No of CN in document- 979
# No of KR in document- 4739
#
#
#
# ------------------------------2006_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US06982339', 'B2', '20060103', 'US10943282', '20040917', 'US', "['Manzer Leo Ernest']", "['Leo Ernest']", "['US']", 'Production of N-aryl-2-lactam and N-cycloalkyl-2-lactam by reductive amination of lactones with aryl amines', '1', "['Deitch Gerald E.']", "['Gerald E.']", '1', '0', '1', '1', '0', '1']
# ['US']
# US06982339
# ['1', 'US06982340', 'B2', '20060103', 'US10384596', '20030311', 'JP', "['Mumura Taku', 'Kadowaki Hidetoshi', 'Nishigaki Futoshi']", "['Taku', 'Hidetoshi', 'Futoshi']", "['JP', 'JP', 'JP']", 'Process for producing an ester', '26', '[]', '[]', '3', '0', '3', '0', '0', '0']
# ['JP', 'JP', 'JP']
# US06982340
# ['2', 'US06982341', 'B1', '20060103', 'US11093995', '20050330', 'US', "['Kim Yunsoo', 'Kim Chang Gyoun', 'Chung Taek-Mo', 'Lee Sun Sook', 'An Ki-Seok', 'Yang Taek Seung', 'Jang Hong Suk']", "['Yunsoo', 'Chang Gyoun', 'Taek-Mo', 'Sun Sook', 'Ki-Seok', 'Taek Seung', 'Hong Suk']", "['KR', 'KR', 'KR', 'KR', 'KR', 'KR', 'KR']", 'Volatile copper aminoalkoxide complex and deposition of copper thin film using same', '6', '[]', '[]', '6', '1', '7', '0', '0', '0']
# ['KR', 'KR', 'KR', 'KR', 'KR', 'KR', 'KR']
# US06982341
#
#
# No of rows in document- 200970
# No of both CN & KR in document- 6
# No of CN in document- 1660
# No of KR in document- 6726
#
#
#
# ------------------------------2007_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US07156755', 'B2', '20070102', 'US10905925', '20050126', 'US', "['Kennedy, III Thomas J.', 'Binette Mark L.']", "['Thomas J.', 'Mark L.']", "['US', 'US']", 'Golf ball with thermoplastic material', '1', "['Catania Michael A.', 'Lo Elaine H.']", "['Michael A.', 'Elaine H.']", '2', '0', '2', '1', '1', '2']
# ['US', 'US']
# US07156755
# ['1', 'US07156756', 'B2', '20070102', 'US11298172', '20051210', 'US', "['Sullivan Michael J.', 'Ladd Derek A.']", "['Michael J.', 'Derek A.']", "['US', 'US']", 'Golf ball containing graphite nanosheets in a polymeric network', '5', "['Wheeler Kristin D.']", "['Kristin D.']", '2', '0', '2', '1', '0', '1']
# ['US', 'US']
# US07156756
# ['2', 'USD0534562', 'S1', '20070102', 'US29242620', '20051110', 'US', "['Pinchot James M.']", "['James M.']", "['US']", 'Extruder plate for diamond shaped extruder insert', '1', "['Turung Brian E.']", "['Brian E.']", '1', '0', '1', '1', '0', '1']
# ['US']
# USD0534562
#
#
# No of rows in document- 187511
# No of both CN & KR in document- 10
# No of CN in document- 1881
# No of KR in document- 7576
#
#
#
# ------------------------------2008_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'USD0558659', 'S1', '20080101', 'US29285776', '20070410', 'US', "['Jackson Jeffrey']", "['Jeffrey']", "['US']", 'Stackable watercraft floatation dock', '1', "['Meeker Donald W.']", "['Donald W.']", '1', '0', '1', '1', '0', '1']
# ['US']
# USD0558659
# ['1', 'US07314542', 'B2', '20080101', 'US11234054', '20050922', 'US', "['Smolko Daniel D.', 'Swanson Paul D.', 'Hodko Dalibor', 'Canter David', 'Haigis Robert W.', 'Patterson Tricia']", "['Daniel D.', 'Paul D.', 'Dalibor', 'David', 'Robert W.', 'Tricia']", "['US', 'US', 'US', 'US', 'US', 'US']", 'Methods and materials for optimization of electronic transportation and hybridization reactions', '19', '[]', '[]', '5', '1', '6', '0', '0', '0']
# ['US', 'US', 'US', 'US', 'US', 'US']
# US07314542
# ['2', 'US07314543', 'B2', '20080101', 'US10685659', '20031014', 'US', "['Fang Ming', 'Dubin Valery M.', 'Haight Scott M.']", "['Ming', 'Valery M.', 'Scott M.']", "['US', 'US', 'US']", 'Tin deposition', '12', '[]', '[]', '3', '0', '3', '0', '0', '0']
# ['US', 'US', 'US']
# US07314543
#
#
# No of rows in document- 189559
# No of both CN & KR in document- 9
# No of CN in document- 2703
# No of KR in document- 9038
#
#
#
# ------------------------------2009_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US07473347', 'B2', '20090106', 'US10471037', '20020305', 'EP', "['Germaine Gilbert Robert Bernard']", "['Gilbert Robert Bernard']", "['FR']", 'Process to prepare a lubricating base oil', '11', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['FR']
# US07473347
# ['1', 'USD0584252', 'S1', '20090106', 'US29304739', '20080306', 'US', "['Lewis, II Richard Evans', 'Lawrence James I.', 'Vicknair Eugene', 'Lazzaro Victor']", "['Richard Evans', 'James I.', 'Eugene', 'Victor']", "['US', 'US', 'US', 'US']", 'Electronic equipment cabinet', '1', "['Wright James D.', 'Tillman Chad D.']", "['James D.', 'Chad D.']", '4', '0', '4', '2', '0', '2']
# ['US', 'US', 'US', 'US']
# USD0584252
# ['2', 'US07473348', 'B2', '20090106', 'US10891971', '20040715', 'DE', "['Koch Christian']", "['Christian']", "['DE']", 'Diesel oil from residues by catalytic depolymerization with energy input from a pump-agitator system', '11', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['DE']
# US07473348
# No of rows in document- 196688
# No of both CN & KR in document- 18
# No of CN in document- 3155
# No of KR in document- 9894
#
#
#
# ------------------------------2010_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US07641587', 'B2', '20100105', 'US11688396', '20070320', 'US', "['Jess Richard B.', 'Sell Jeffrey A.', 'Marano John E.', 'Verdejo Julian R.']", "['Richard B.', 'Jeffrey A.', 'John E.', 'Julian R.']", "['US', 'US', 'US', 'US']", 'Fuel quality indication for adaptive transmission control', '18', '[]', '[]', '4', '0', '4', '0', '0', '0']
# ['US', 'US', 'US', 'US']
# US07641587
# ['1', 'US07641588', 'B2', '20100105', 'US11700196', '20070131', 'US', "['Thomson Norval P.', 'Martinez, Jr. Alberto']", "['Norval P.', 'Alberto']", "['US', 'US']", 'CVT system having discrete selectable speed ranges', '20', '[]', '[]', '2', '0', '2', '0', '0', '0']
# ['US', 'US']
# US07641588
# ['2', 'USD0607390', 'S1', '20100105', 'US29314597', '20090413', 'DE', "['Krauss Matthias']", "['Matthias']", "['DE']", 'Air channel trim of an automobile', '1', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['DE']
# USD0607390
#
#
# No of rows in document- 250551
# No of both CN & KR in document- 27
# No of CN in document- 4549
# No of KR in document- 12894
#
#
#
# ------------------------------2011_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'USD0630192', 'S1', '20110104', 'US29343020', '20090904', 'US', "['Heppener Axel']", "['Axel']", "['DE']", 'Conference communication unit', '1', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['DE']
# USD0630192
# ['1', 'US07862303', 'B2', '20110104', 'US11871320', '20071012', 'US', "['Sleiman Mohamad', 'Dion Michel', 'Girgis Sami']", "['Mohamad', 'Michel', 'Sami']", "['CA', 'CA', 'CA']", 'Compressor turbine vane airfoil profile', '15', '[]', '[]', '3', '0', '3', '0', '0', '0']
# ['CA', 'CA', 'CA']
# US07862303
# ['2', 'USD0630193', 'S1', '20110104', 'US29361507', '20100512', 'US', "['Bennett Betty Ann']", "['Betty Ann']", "['US']", 'Electronic device', '1', '[]', '[]', '0', '1', '1', '0', '0', '0']
# ['US']
# USD0630193
#
#
# No of rows in document- 254067
# No of both CN & KR in document- 23
# No of CN in document- 5069
# No of KR in document- 13630
#
#
#
# ------------------------------2012_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US08087988', 'B2', '20120103', 'US10871876', '20040617', 'US', "['Nguyen Binh T.', 'Paulsen Craig A.', 'Muir David H.']", "['Binh T.', 'Craig A.', 'David H.']", "['US', 'US', 'AU']", 'Personal gaming device and method of presenting a game', '49', '[]', '[]', '2', '1', '3', '0', '0', '0']
# ['US', 'US', 'AU']
# US08087988
# ['1', 'US08087989', 'B2', '20120103', 'US12221495', '20080804', 'US', "['Shimshi Ezra']", "['Ezra']", "['US']", 'Apparatus for making a sought-after choice more likely to be obtained by a participant from a group of choices', '6', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['US']
# US08087989
# ['2', 'USD0651566', 'S1', '20120103', 'US29372474', '20101124', 'US', "['Sedberry Erica', 'Lockhart Jack', 'Thompson Lance', 'Chung Wai Wah', 'May Randall']", "['Erica', 'Jack', 'Lance', 'Wai Wah', 'Randall']", "['US', 'US', 'US', 'CN', 'US']", 'Transformer', '1', '[]', '[]', '4', '1', '5', '0', '0', '0']
# ['US', 'US', 'US', 'CN', 'US']
# USD0651566
#
#
# No of rows in document- 283408
# No of both CN & KR in document- 39
# No of CN in document- 6996
# No of KR in document- 14598
#
#
#
# ------------------------------2013_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US08342542', 'B2', '20130101', 'US12531033', '20080402', 'JP', "['Sagara Kenji', 'Kageyama Yusuke', 'Kawabe Yoshihiro', 'Nishida Masahiko', 'Watanabe Isao', 'Kunitomo Masaya', 'Ohta Masaki']", "['Kenji', 'Yusuke', 'Yoshihiro', 'Masahiko', 'Isao', 'Masaya', 'Masaki']", "['JP', 'JP', 'JP', 'JP', 'JP', 'JP', 'JP']", 'Suspension device and method for supporting a wheel', '27', '[]', '[]', '7', '0', '7', '0', '0', '0']
# ['JP', 'JP', 'JP', 'JP', 'JP', 'JP', 'JP']
# US08342542
# ['1', 'US08342543', 'B2', '20130101', 'US12647615', '20091228', 'US', "['Fernandez Javier']", "['Javier']", "['US']", 'Method for draining and transporting large diameter hoses', '12', "['Heino Joseph S.', 'Bergin Patrick M.']", "['Joseph S.', 'Patrick M.']", '1', '0', '1', '2', '0', '2']
# ['US']
# US08342543
# ['2', 'USD0673543', 'S1', '20130101', 'US29397175', '20110712', 'US', "['Melanson Christopher', 'Havens Adam', 'Willes Stephen']", "['Christopher', 'Adam', 'Stephen']", "['US', 'US', 'US']", 'Case for electronic device', '1', '[]', '[]', '3', '0', '3', '0', '0', '0']
# ['US', 'US', 'US']
# USD0673543
#
#
# No of rows in document- 310280
# No of both CN & KR in document- 38
# No of CN in document- 8599
# No of KR in document- 16238
#
#
#
# ------------------------------2014_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US08622366', 'B2', '20140107', 'US12877151', '20100908', 'US', "['Bachmann Rene', 'Brinkmann Ulrike', 'Grosse Kersten']", "['Rene', 'Ulrike', 'Kersten']", "['DE', 'DE', 'DE']", 'Manually operable drive module', '20', '[]', '[]', '2', '1', '3', '0', '0', '0']
# ['DE', 'DE', 'DE']
# US08622366
# ['1', 'US08622367', 'B2', '20140107', 'US13106621', '20110512', 'US', "['Lovell Michel Ken', 'Grabau Ted Dennis']", "['Michel Ken', 'Ted Dennis']", "['US', 'US']", 'Low friction live-loaded packing', '16', "['Furmanek Michael P.']", "['Michael P.']", '2', '0', '2', '1', '0', '1']
# ['US', 'US']
# US08622367
# ['2', 'US08622368', 'B2', '20140107', 'US13020248', '20110203', 'EP', "['Geiser Friedrich']", "['Friedrich']", "['AT']", 'Flap transfer valve with pivotable valve closure beam', '15', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['AT']
# US08622368
#
#
# No of rows in document- 334111
# No of both CN & KR in document- 34
# No of CN in document- 10101
# No of KR in document- 18830
#
#
#
# ------------------------------2015_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US08925789', 'B2', '20150106', 'US13224514', '20110902', 'DE', "['Schäfer Michael', 'Schmitt Wolfgang']", "['Michael', 'Wolfgang']", "['DE', 'DE']", 'Contacting means and method for contacting electrical components', '13', '[]', '[]', '2', '0', '2', '0', '0', '0']
# ['DE', 'DE']
# US08925789
# ['1', 'USD0720666', 'S1', '20150106', 'US29473176', '20131119', 'US', "['Farmer Edmund', 'Griswold Lee']", "['Edmund', 'Lee']", "['US', 'US']", 'Handle for a buggy', '1', '[]', '[]', '2', '0', '2', '0', '0', '0']
# ['US', 'US']
# USD0720666
# ['2', 'US08925790', 'B1', '20150106', 'US13409995', '20120301', 'US', "['Edel David']", "['David']", "['US']", 'Method for attaching the hosel to a putter head', '15', "['Gonzales Ellen M.']", "['Ellen M.']", '1', '0', '1', '0', '1', '1']
# ['US']
# US08925790
# No of rows in document- 334129
# No of both CN & KR in document- 56
# No of CN in document- 11232
# No of KR in document- 20992
#
#
#
# ------------------------------2016_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'USD0746541', 'S1', '20160105', 'US29490315', '20140508', 'US', "['Sambashivan Sidharth']", "['Sidharth']", "['US']", 'Snack food product', '1', "['Cahoon Colin P.', 'Orr Celina M.']", "['Colin P.', 'Celina M.']", '1', '0', '1', '1', '1', '2']
# ['US']
# USD0746541
# ['1', 'USD0746542', 'S1', '20160105', 'US29490956', '20140515', 'US', "['Gilroy Brian']", "['Brian']", "['US']", 'Combined pair of suspenders and attachment members', '1', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['US']
# USD0746542
# ['2', 'USD0746544', 'S1', '20160105', 'US29504333', '20141003', 'US', "['Curran David Jeffrey']", "['David Jeffrey']", "['US']", 'Convertible shorts', '1', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['US']
# USD0746544
#
#
# No of rows in document- 310049
# No of both CN & KR in document- 62
# No of CN in document- 12912
# No of KR in document- 21704
#
#
#
# ------------------------------2017_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'USD0775450', 'S1', '20170103', 'US29562280', '20160425', 'US', "['Kimura Ryusuke', 'Kajio Fusaki']", "['Ryusuke', 'Fusaki']", "['JP', 'JP']", 'Macaroni', '1', '[]', '[]', '1', '1', '2', '0', '0', '0']
# ['JP', 'JP']
# USD0775450
# ['1', 'USD0775451', 'S1', '20170103', 'US29562286', '20160425', 'US', "['Kimura Ryusuke', 'Kajio Fusaki']", "['Ryusuke', 'Fusaki']", "['JP', 'JP']", 'Macaroni', '1', '[]', '[]', '1', '1', '2', '0', '0', '0']
# ['JP', 'JP']
# USD0775451
# ['2', 'USD0775452', 'S1', '20170103', 'US29459093', '20130626', 'US', "['Brownell Annabelle Abba', 'Heafitz Betsy Catya']", "['Annabelle Abba', 'Betsy Catya']", "['US', 'US']", 'Combination cleavage-enhancing garment insert and set of insert covers', '1', '[]', '[]', '0', '2', '2', '0', '0', '0']
# ['US', 'US']
# USD0775452
#
#
# No of rows in document- 327399
# No of both CN & KR in document- 49
# No of CN in document- 15921
# No of KR in document- 22482
#
#
#
# ------------------------------2018_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'USD0806351', 'S1', '20180102', 'US29576672', '20160906', 'US', "['Belt Sarah', 'Thorogood Christopher J.']", "['Sarah', 'Christopher J.']", "['GB', 'GB']", 'Food product', '1', '[]', '[]', '1', '1', '2', '0', '0', '0']
# ['GB', 'GB']
# USD0806351
# ['1', 'USD0806352', 'S1', '20180102', 'US29570127', '20160705', 'KR', "['Baek Seung Soon']", "['Seung Soon']", "['KR']", 'Necktie', '1', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['KR']
# USD0806352
# ['2', 'USD0806353', 'S1', '20180102', 'US29546874', '20151126', 'US', "['Aitch Lauren']", "['Lauren']", "['US']", 'Undershirt', '1', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['US']
# USD0806353
#
#
# No of rows in document- 316379
# No of both CN & KR in document- 42
# No of CN in document- 17265
# No of KR in document- 21461
#
#
#
# ------------------------------2019_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US10171856', 'B2', '20190101', 'US15016150', '20160204', 'US', "['Phipps Jason N.', 'Daws Sally A.', 'Gibbons Stephanie L.', 'Havens Kimberly M.', 'Duffy Megan E.', 'Motwani Sandeep', 'Cuadra Robert A.', 'Applebaum Sam M.', 'Samos Juni']", "['Jason N.', 'Sally A.', 'Stephanie L.', 'Kimberly M.', 'Megan E.', 'Sandeep', 'Robert A.', 'Sam M.', 'Juni']", "['US', 'US', 'US', 'US', 'US', 'US', 'US', 'US', 'US']", 'Viewer-authored content acquisition and management system for in-the-moment broadcast in conjunction with media programs', '31', '[]', '[]', '7', '2', '9', '0', '0', '0']
# ['US', 'US', 'US', 'US', 'US', 'US', 'US', 'US', 'US']
# US10171856
# ['1', 'US10171857', 'B2', '20190101', 'US15426092', '20170207', 'US', "['Ren Dahai', 'Qian Yuhui', 'Chen Ming', 'Hao Jianxiu']", "['Dahai', 'Yuhui', 'Ming', 'Jianxiu']", "['US', 'US', 'US', 'US']", 'Network data delivery sponsorship signatures in streaming manifest files', '20', '[]', '[]', '2', '2', '4', '0', '0', '0']
# ['US', 'US', 'US', 'US']
# US10171857
# ['2', 'US10171858', 'B2', '20190101', 'US15448110', '20170302', 'US', "['George William', 'Smith Kevin']", "['William', 'Kevin']", "['US', 'US']", 'Utilizing biometric data to enhance virtual reality content and user response', '20', '[]', '[]', '2', '0', '2', '0', '0', '0']
# ['US', 'US']
# US10171858
#
#
# No of rows in document- 400694
# No of both CN & KR in document- 64
# No of CN in document- 26243
# No of KR in document- 24653
#
#
#
# ------------------------------2020_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US10529737', 'B2', '20200107', 'US16435887', '20190610', 'US', "['Purayath Vinod R.']", "['Vinod R.']", "['US']", 'Accommodating imperfectly aligned memory holes', '19', '[]', '[]', '1', '0', '1', '0', '0', '0']
# ['US']
# US10529737
# ['1', 'US10529738', 'B2', '20200107', 'US15140863', '20160428', 'US', "['Purakh Raj Verma', 'Zhang Shaoqiang', 'Toh Rui Tze']", "['Raj Verma', 'Shaoqiang', 'Rui Tze']", "['SG', 'SG', 'SG']", 'Integrated circuits with selectively strained device regions and methods for fabricating same', '9', '[]', '[]', '2', '1', '3', '0', '0', '0']
# ['SG', 'SG', 'SG']
# US10529738
# ['2', 'US10529739', 'B2', '20200107', 'US15378680', '20161214', 'US', "['Leobandung Effendi']", "['Effendi']", "['US']", 'Asymmetric band gap junctions in narrow band gap MOSFET', '12', "['Kelly L. Jeffrey']", "['L. Jeffrey']", '0', '1', '1', '1', '0', '1']
# ['US']
# US10529739
#
#
# No of rows in document- 398950
# No of both CN & KR in document- 73
# No of CN in document- 30334
# No of KR in document- 24776
#
#
#
# ------------------------------2021_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US10886548', 'B2', '20210105', 'US15309280', '20150507', 'US', "['Milnes Thomas B.', 'Humplik Thomas', 'McKay Ian S.']", "['Thomas B.', 'Thomas', 'Ian S.']", "['US', 'US', 'US']", 'Hydrogen management in electrochemical systems', '9', '[]', '[]', '3', '0', '3', '0', '0', '0']
# ['US', 'US', 'US']
# US10886548
# ['1', 'US10886549', 'B2', '20210105', 'US15961916', '20180425', 'US', "['Zou Yuquan', 'McDermid Scott', 'Cimenti Massimiliano', 'Yang Shun-wen Amy', 'Catoiu Liviu']", "['Yuquan', 'Scott', 'Massimiliano', 'Shun-wen Amy', 'Liviu']", "['CA', 'CA', 'CA', 'CA', 'CA']", 'Catalyst coated membranes and preparation methods for fuel cells', '24', "['Pendorf Stephan A.']", "['Stephan A.']", '4', '1', '5', '1', '0', '1']
# ['CA', 'CA', 'CA', 'CA', 'CA']
# US10886549
# ['2', 'US10886550', 'B2', '20210105', 'US16212275', '20181206', 'KR', "['Woo Hee Jin', 'Lee Ki Sub']", "['Hee Jin', 'Ki Sub']", "['KR', 'KR']", 'Membrane electrode assembly', '9', '[]', '[]', '2', '0', '2', '0', '0', '0']
# ['KR', 'KR']
# US10886550
# No of rows in document- 371926
# No of both CN & KR in document- 64
# No of CN in document- 33768
# No of KR in document- 23690
#
#
#
# ------------------------------2022_patent_grant_processed.csv------------------------------
# 20
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']
# inventor_country
# publication_id
# ['0', 'US11218467', 'B2', '20220104', 'US16249715', '20190116', 'US', "['Kharidehal Chandra Mouli', 'Rathi Sumit', 'deep Gagan', 'Das Santosh Kumar']", "['Chandra Mouli', 'Sumit', 'Gagan', 'Santosh Kumar']", "['IN', 'IN', 'IN', 'IN']", 'System and method for authentication as a service', '20', '[]', '[]', '4', '0', '4', '0', '0', '0']
# ['IN', 'IN', 'IN', 'IN']
# US11218467
# ['1', 'US11218468', 'B2', '20220104', 'US16291907', '20190304', 'US', "['Dhamankar Shailendra', 'Babu Krishnaraj', 'Seward Shelby', 'Meka Srinivas']", "['Shailendra', 'Krishnaraj', 'Shelby', 'Srinivas']", "['US', 'US', 'US', 'US']", 'MSISDN request handling for identity fraud management', '20', '[]', '[]', '4', '0', '4', '0', '0', '0']
# ['US', 'US', 'US', 'US']
# US11218468
# ['2', 'US11218469', 'B2', '20220104', 'US16294787', '20190306', 'US', "['Valites Matthew C.', 'Bollinger Jeffrey Bryan', 'Halvorsen Ian Anders']", "['Matthew C.', 'Jeffrey Bryan', 'Ian Anders']", "['US', 'US', 'US']", 'Systems and methods for controlling personal information on online services', '12', '[]', '[]', '3', '0', '3', '0', '0', '0']
# ['US', 'US', 'US']
# US11218469
#
#
# No of rows in document- 80167
# No of both CN & KR in document- 14
# No of CN in document- 8318
# No of KR in document- 5285
#
#
#
#
#
# Total no of rows in all documents- 4907828
# Total CN & KR in all documents- 631
# Total CN in all documents- 201685
# Total KR in all documents- 279206
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size']

# %% [markdown]
# # Filtering and saving KR & CN Data.

# %%
cn_kr_rows = []

head = None
    
file_name = str(2005) + "_patent_grant_processed.csv"

print("\n"+"-"*30 + file_name + "-"*30)

with open("Team 1 Processed Data/"+file_name, 'r',encoding="utf8") as file:
    csvreader = csv.reader(file)

    count = 0

    for row in csvreader:

        if count==0:
            if row!=head:
                head = row

        count+=1


        if 'KR' in row[9] or 'CN' in row[9]:

            row.append(str(i))
            cn_kr_rows.append(row)          

print("\n")
print("No of rows in document-",count)

print("\n\n")
print(len(cn_kr_rows))
head = head + ["Year"]
print(head)
# Out:
# ------------------------------2005_patent_grant_processed.csv------------------------------
#
#
# No of rows in document- 160990
#
#
#
# 5721
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size', 'Year']

# %%
with open("2005_CN_KR_patent_grant_processed.csv", mode='w', newline='',encoding="utf8") as file_1:
    
    writer = csv.writer(file_1)
    writer.writerow(head)
    writer.writerows(cn_kr_rows)

# %%
s = "USD0806352"
s = s.replace('0', '', 1)
s
# Out:
# 'USD806352'

# %%
with open("2005_CN_KR_patent_grant_processed.csv", 'r',encoding="utf8") as file:
    csvreader = csv.reader(file)

    count = 0

    for row in csvreader:

        if count==0:
            print(len(row))

        count+=1

        if count<20:
            print(row)
        
print(count)
# Out:
# 21
# ['', 'publication_id', 'publication_kind', 'publication_date', 'application_id', 'application_date', 'country', 'inventor_name', 'inventor_firstname', 'inventor_country', 'invention_title', 'number_of_claims', 'attorney_name', 'attorney_firstname', 'inventor males', 'inventor females', 'inventor team size', 'attorney males', 'attorney females', 'attorney team size', 'Year']
# ['34', 'US06838172', 'B2', '20050104', 'US10475776', '20020426', 'KR', "['Yoon Joon-Young', 'Choi Yoeng-Beek']", "['Joon-Young', 'Yoeng-Beek']", "['KR', 'KR']", 'Sea-island typed conjugate multi filament comprising dope dyeing component and a process of preparing for the same', '18', '[]', '[]', '1', '1', '2', '0', '0', '0', '2022']
# ['75', 'US06838206', 'B2', '20050104', 'US09967456', '20010928', 'KR', "['Kim Soo-Ryoung', 'Byun Ho-Kyung', 'Kim Yong-Rae', 'Yoo Kwang-Ho', 'Kim Jee-Ho']", "['Soo-Ryoung', 'Ho-Kyung', 'Yong-Rae', 'Kwang-Ho', 'Jee-Ho']", "['KR', 'KR', 'KR', 'KR', 'KR']", 'Safety plate of secondary battery', '13', '[]', '[]', '5', '0', '5', '0', '0', '0', '2022']
# ['96', 'US06838223', 'B2', '20050104', 'US10364406', '20030212', 'KR', "['Yoon Sang-woong', 'Chung Hoe-sik', 'Ryu Jin-a', 'Kim Young-ho']", "['Sang-woong', 'Hoe-sik', 'Jin-a', 'Young-ho']", "['KR', 'KR', 'KR', 'KR']", 'Compositions for anti-reflective light absorbing layer and method for forming patterns in semiconductor device using the same', '30', '[]', '[]', '3', '1', '4', '0', '0', '0', '2022']
# ['147', 'US06836961', 'B2', '20050104', 'US10751209', '20031230', 'KR', "['Kang Byoung Young']", "['Byoung Young']", "['KR']", 'Ceramic packaging method employing flip-chip bonding', '7', "['Fortney Andrew D.']", "['Andrew D.']", '1', '0', '1', '1', '0', '1', '2022']
# ['148', 'US06836961', 'B2', '20050104', 'US10751209', '20031230', 'KR', "['Kang Byoung Young']", "['Byoung Young']", "['KR']", 'Ceramic packaging method employing flip-chip bonding', '7', "['Fortney Andrew D.']", "['Andrew D.']", '1', '0', '1', '1', '0', '1', '2022']
# ['204', 'US06838280', 'B2', '20050104', 'US10375190', '20030225', 'US', "['Kim Sunyoung', 'Yu Seung Shin', 'Hong Youngtae', 'Kim Jong-Mook', 'Han Eun Young']", "['Sunyoung', 'Seung Shin', 'Youngtae', 'Jong-Mook', 'Eun Young']", "['KR', 'KR', 'KR', 'KR', 'KR']", 'Construction of high efficiency retroviral vector for gene therapy of hunter syndrome', '1', '[]', '[]', '3', '2', '5', '0', '0', '0', '2022']
# ['205', 'US06838280', 'B2', '20050104', 'US10375190', '20030225', 'US', "['Kim Sunyoung', 'Yu Seung Shin', 'Hong Youngtae', 'Kim Jong-Mook', 'Han Eun Young']", "['Sunyoung', 'Seung Shin', 'Youngtae', 'Jong-Mook', 'Eun Young']", "['KR', 'KR', 'KR', 'KR', 'KR']", 'Construction of high efficiency retroviral vector for gene therapy of hunter syndrome', '1', '[]', '[]', '3', '2', '5', '0', '0', '0', '2022']
# ['233', 'US06838298', 'B2', '20050104', 'US10290837', '20021108', 'KR', "['Lee Ju-Il']", "['Ju-Il']", "['KR']", 'Method of manufacturing image sensor for reducing dark current', '14', '[]', '[]', '1', '0', '1', '0', '0', '0', '2022']
# ['265', 'US06838326', 'B2', '20050104', 'US10329680', '20021227', 'KR', "['Kwon Ho Yup']", "['Ho Yup']", "['KR']", 'Semiconductor device, and method for manufacturing the same', '8', '[]', '[]', '1', '0', '1', '0', '0', '0', '2022']
# ['270', 'US06838330', 'B2', '20050104', 'US10445843', '20030528', 'KR', "['Moon Bong-Ho', 'Cheol Ju-Yun', 'Ko Yong-Sun', 'Hwang In-Seak']", "['Bong-Ho', 'Ju-Yun', 'Yong-Sun', 'In-Seak']", "['KR', 'KR', 'KR', 'KR']", 'Method of forming a contact hole of a semiconductor device', '13', '[]', '[]', '4', '0', '4', '0', '0', '0', '2022']
# ['280', 'US06838339', 'B2', '20050104', 'US10456648', '20030605', 'US', "['Lee Heon']", "['Heon']", "['KR']", 'Area-efficient stack capacitor', '14', '[]', '[]', '0', '1', '1', '0', '0', '0', '2022']
# ['283', 'US06838341', 'B2', '20050104', 'US10688079', '20031016', 'KR', "['Yoon Jae-Man', 'Lee Yun-Jae', 'Lee Sang-Hyun', 'Kim Wook-Je']", "['Jae-Man', 'Yun-Jae', 'Sang-Hyun', 'Wook-Je']", "['KR', 'KR', 'KR', 'KR']", 'Method for fabricating semiconductor device with self-aligned storage node', '14', '[]', '[]', '4', '0', '4', '0', '0', '0', '2022']
# ['313', 'US06838369', 'B2', '20050104', 'US10608116', '20030630', 'KR', "['Lee Ho Seok', 'Kim Dong Sauk', 'Kim Jin Woong']", "['Ho Seok', 'Dong Sauk', 'Jin Woong']", "['KR', 'KR', 'KR']", 'Method for forming contact hole of semiconductor device', '4', '[]', '[]', '2', '1', '3', '0', '0', '0', '2022']
# ['324', 'US06838378', 'B2', '20050104', 'US10329679', '20021227', 'KR', "['Lee Sung Joon']", "['Sung Joon']", "['KR']", 'Method for manufacturing semiconductor device', '8', '[]', '[]', '1', '0', '1', '0', '0', '0', '2022']
# ['373', 'US06838416', 'B2', '20050104', 'US10363808', '20010905', 'KR', "['Ryu Eung-Kul', 'Kim Hyoung-Rae', 'Jeon Dong-Ju', 'Song Jong-Whan', 'Kim Kyoung-Mahn', 'Lee Jung-No', 'Kim Hyoung-Cheul', 'Hong Kyung-Sik']", "['Eung-Kul', 'Hyoung-Rae', 'Dong-Ju', 'Jong-Whan', 'Kyoung-Mahn', 'Jung-No', 'Hyoung-Cheul', 'Kyung-Sik']", "['KR', 'KR', 'KR', 'KR', 'KR', 'KR', 'KR', 'KR']", 'Herbicidal 5-benzyloxymethyl-1,2-isoxazoline derivatives', '13', '[]', '[]', '4', '4', '8', '0', '0', '0', '2022']
# ['480', 'US06838481', 'B1', '20050104', 'US09869505', '19991214', 'KR', "['Kim Cheong-Taek', 'Kim Ho-Jeong', 'Jin Mu-Hyun', 'Jung Min-Hwan', 'Won Jung-Mi']", "['Cheong-Taek', 'Ho-Jeong', 'Mu-Hyun', 'Min-Hwan', 'Jung-Mi']", "['KR', 'KR', 'KR', 'KR', 'KR']", 'Skin whitener', '12', '[]', '[]', '2', '3', '5', '0', '0', '0', '2022']
# ['495', 'US06838490', 'B2', '20050104', 'US10049333', '20010615', 'CN', "['Zhang Xiaohong', 'Qiao Jinliang', 'Wei Genshuan', 'Gao Jianming', 'Liu Yiqun', 'Zhang Shijun', 'Song Zhihai', 'Li Jiuqiang', 'Zhu Yicai']", "['Xiaohong', 'Jinliang', 'Genshuan', 'Jianming', 'Yiqun', 'Shijun', 'Zhihai', 'Jiuqiang', 'Yicai']", "['CN', 'CN', 'CN', 'CN', 'CN', 'CN', 'CN', 'CN', 'CN']", 'Silicone rubber in the form of a finely divided powder, method for the production and the use of the same', '33', '[]', '[]', '4', '5', '9', '0', '0', '0', '2022']
# ['505', 'US06838497', 'B2', '20050104', 'US10230965', '20020829', 'KR', "['Hong Sang-Hyun', 'Jang Bok-Nam', 'Chang Young-Kil', 'Ahn Sung-Hee', 'Yang Jae-Ho']", "['Sang-Hyun', 'Bok-Nam', 'Young-Kil', 'Sung-Hee', 'Jae-Ho']", "['KR', 'KR', 'KR', 'KR', 'KR']", 'Flame retardant thermoplastic resin composition containing styrene polymer as compatabilizer and oxaphospholane compound as flame retardant', '20', "['Tungol Maria Parrish']", "['Maria Parrish']", '4', '1', '5', '0', '1', '1', '2022']
# 5722

# %% [markdown]
# # Getting CN & KR Patent Numbers

# %%
def return_cn_kr_numbers(number):
    
    if len(number)==0:
        return ["No Application Number"], ["No Application Number"]
    
    if number[0:4] == "USD0":
        number = number.replace('0', '', 1)
    elif number[0:3] == "US0":
        number = number.replace('0', '', 1)
    
    # ~ Initialize scraper class ~ #
    scraper=scraper_class()

    # ~~ Scrape patents individually ~~ #
    err, soup, url = scraper.request_single_patent(number)
    
    if err==404:
        return ["Patent not found"], ["Patent not found"]

    app_by_year = soup.find_all('li', itemprop='applicationsByYear')

    apps = []
    for x in app_by_year:
        ap = x.find_all('li', itemprop='application')
        apps = apps + ap

    patents = []
    #urls = []
    
    print(len(apps))

    for y in apps:
        if y.find_all('span',itemprop='countryCode')[0].text == 'CN' or y.find_all('span',itemprop='countryCode')[0].text == 'KR':
            url = y.find_all('span',itemprop='documentId')[0].text
            #urls.append(url)
            patents.append(url[7:])

    #print(urls)
    print(patents)
    #print("\n")
    
    if len(patents)==0:
        return ["No KR or CN Application Number"], ["No KR or CN Application Number"]
    
    names = []
    
    for p in patents:

        err_a, soup_a, url_a = scraper.request_single_patent(p)

        # ~ Parse results of scrape ~ #
        patent_p = scraper.get_scraped_data(soup_a,p,url_a)

        n = []
        
        # ~ Print inventors of patents ~ 
        for inventor in json.loads(patent_p['inventor_name']):
            #print('Patent inventor : {0}'.format(inventor['inventor_name']))
            n.append(inventor['inventor_name'])
        
        names.append(n)
    print(names)

    print("\n")
    return patents, names

# %%
cn_kr_patents_rows = []

# %%
with open("2005_CN_KR_patent_grant_processed.csv", 'r',encoding="utf8") as file:
    csvreader = csv.reader(file)
    
    cn_kr_patents_rows = []
    
    count = 0

    for row in csvreader:
        
        if count%100==0 and count>0:
            with open("2005_CN_KR_patent_grant_processed_names.csv", mode='a', newline='',encoding="utf8") as file_3:
                writer = csv.writer(file_3)
                writer.writerows(cn_kr_patents_rows)
                print(count)
                print("="*50+"SAVED"+"="*50)
                cn_kr_patents_rows = []

        if count==0:
            
            row.append("WorldWide Applications")
            row.append("Original Names")
            
            cn_kr_patents_rows.append(row)
            
            print(len(row))
            print(row)
            print("\n\n")
            count+=1
            continue
        
        try:
            patents, names = return_cn_kr_numbers(row[1])
        except Exception as e:
            print(e)
            patents, names = [str(e)], [str(e)]
        
        row.append(patents)
        row.append(names)
        
        print(count,"\n\n")
        
        count+=1
        
        cn_kr_patents_rows.append(row)


        #if count<20:
        #    print(row)

if len(cn_kr_patents_rows)>0:
    with open("2005_CN_KR_patent_grant_processed_names.csv", mode='a', newline='',encoding="utf8") as file_3:
        writer = csv.writer(file_3)
        writer.writerows(cn_kr_patents_rows)
        print(count)
        print("="*50+"SAVED"+"="*50)
        cn_kr_patents_rows = []

# %%
import pandas as pd

# %%
df = pd.read_csv("2005_CN_KR_patent_grant_processed_names.csv")
df.head()
# Out:
#    Unnamed: 0 publication_id publication_kind  publication_date  \
# 0          34     US06838172               B2          20050104
# 1          75     US06838206               B2          20050104
# 2          96     US06838223               B2          20050104
# 3         147     US06836961               B2          20050104
# 4         148     US06836961               B2          20050104
#
#   application_id  application_date country  \
# 0     US10475776          20020426      KR
# 1     US09967456          20010928      KR
# 2     US10364406          20030212      KR
# 3     US10751209          20031230      KR
# 4     US10751209          20031230      KR
#
#                                        inventor_name  \
# 0             ['Yoon Joon-Young', 'Choi Yoeng-Beek']
# 1  ['Kim Soo-Ryoung', 'Byun Ho-Kyung', 'Kim Yong-...
# 2  ['Yoon Sang-woong', 'Chung Hoe-sik', 'Ryu Jin-...
# 3                              ['Kang Byoung Young']
# 4                              ['Kang Byoung Young']
#
#                                   inventor_firstname  \
# 0                       ['Joon-Young', 'Yoeng-Beek']
# 1  ['Soo-Ryoung', 'Ho-Kyung', 'Yong-Rae', 'Kwang-...
# 2     ['Sang-woong', 'Hoe-sik', 'Jin-a', 'Young-ho']
# 3                                   ['Byoung Young']
# 4                                   ['Byoung Young']
#
#                  inventor_country  ... attorney_firstname  inventor males  \
# 0                    ['KR', 'KR']  ...                 []               1
# 1  ['KR', 'KR', 'KR', 'KR', 'KR']  ...                 []               5
# 2        ['KR', 'KR', 'KR', 'KR']  ...                 []               3
# 3                          ['KR']  ...      ['Andrew D.']               1
# 4                          ['KR']  ...      ['Andrew D.']               1
#
#   inventor females inventor team size  attorney males  attorney females  \
# 0                1                  2               0                 0
# 1                0                  5               0                 0
# 2                1                  4               0                 0
# 3                0                  1               1                 0
# 4                0                  1               1                 0
#
#    attorney team size  Year  WorldWide Applications  \
# 0                   0  2022       ['CN1313657C/en']
# 1                   0  2022       ['CN1193443C/en']
# 2                   0  2022   ['KR20030068729A/en']
# 3                   1  2022   ['KR20040060124A/en']
# 4                   1  2022   ['KR20040060124A/en']
#
#                           Original Names
# 0                       [['尹浚荣', '崔营百']]
# 1  [['金秀铃', '边镐庆', '金勇来', '刘光虎', '金智浩']]
# 2         [['윤상웅', '정회식', '류진아', '김영호']]
# 3                              [['강병영']]
# 4                              [['강병영']]
#
# [5 rows x 23 columns]

# %%
df["WorldWide Applications"].value_counts()
# Out:
# ['No KR or CN Application Number']                                                         1394
# ['Patent not found']                                                                         10
# ['KR100674423B1/en', 'CN100527834C/en', 'CN1260932C/en']                                      4
# ['KR100389130B1/en']                                                                          4
# ['CN1242389C/en', 'CN1156848C/en', 'CN100380506C/en', 'CN1303600C/en', 'CN1180427C/en']       3
#                                                                                            ...
# ['KR100489604B1/en', 'CN1255846C/en']                                                         1
# ['KR20030062797A/en']                                                                         1
# ['KR100476202B1/en']                                                                          1
# ['KR100449950B1/en']                                                                          1
# ['CN100460590C/en']                                                                           1
# Name: WorldWide Applications, Length: 4239, dtype: int64

# %%
scraper=scraper_class()
err, soup, url = scraper.request_single_patent("US6849997")
print(err)
print(type(err))
print(err==404)
print(soup)
print(url)
# Out:
# https://patents.google.com/patent/US6849997
# Patent: US6849997, Error Status Code : 404
# 404
# <class 'int'>
# True
#
# https://patents.google.com/patent/US6849997

# %%
scraper=scraper_class()
err, soup, url = scraper.request_single_patent("US6849992")
print(err)
print(err==404)
print(type(soup))
print(url)
# Out:
# https://patents.google.com/patent/US6849992
# Success
# False
# <class 'bs4.BeautifulSoup'>
# https://patents.google.com/patent/US6849992

# %%
import pandas as pd

df = pd.read_csv('inventor_data with patent number and claims number.csv')
df[df['inventor_country_code'].isin(['KR', 'CN'])].to_csv('inventors_filtered_by_cn_kr.csv', index=False)
# Out:
#           application_number filing_date inventor_name_first  \
# 42                   9331991  2000-01-03                 SEO
# 43                   9331991  2000-01-03              KUIWON
# 44                   9331991  2000-01-03            ICK-CHAN
# 45                   9331991  2000-01-03            YONG-HEE
# 46                   9331991  2000-01-03                 JAE
# ...                      ...         ...                 ...
# 13367205            17135301  2020-12-28             Sung An
# 13367206            17135301  2020-12-28           Yongjoong
# 13367207            17135301  2020-12-28             Bongnam
# 13367208            17135033  2020-12-28           Kye-Hyeon
# 13367209            17135033  2020-12-28             Bongnam
#
#          inventor_name_middle inventor_name_last   gender  inventor_rank  \
# 42                      YOUNG              JEONG     andy            1.0
# 43                        NaN               CHOI  unknown            2.0
# 44                        NaN               KWON  unknown            3.0
# 45                        NaN                KIM   female            4.0
# 46                       BONG               CHOI     andy            5.0
# ...                       ...                ...      ...            ...
# 13367205                  NaN              GWEON  unknown            1.0
# 13367206                  NaN                KIM  unknown            2.0
# 13367207                  NaN               KANG  unknown            3.0
# 13367208                  NaN                KIM  unknown            1.0
# 13367209                  NaN               KANG  unknown            2.0
#
#          inventor_country_code    pat_no  claim_no
# 42                          KR   6451348       NaN
# 43                          KR   6451348       NaN
# 44                          KR   6451348       NaN
# 45                          KR   6451348       NaN
# 46                          KR   6451348       NaN
# ...                        ...       ...       ...
# 13367205                    KR  10970633       NaN
# 13367206                    KR  10970633       NaN
# 13367207                    KR  10970633       NaN
# 13367208                    KR  10970645       NaN
# 13367209                    KR  10970645       NaN
#
# [1265326 rows x 10 columns]
